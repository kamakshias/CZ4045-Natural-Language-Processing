# %%
# !git clone https://github.com/AtrikDas/nlp-assignment-2.git
# Out:
# Cloning into 'nlp-assignment-2'...
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 33 (delta 15), reused 25 (delta 7), pack-reused 0
# Unpacking objects: 100% (33/33), done.

# %%
cd 'nlp-assignment-2'
# Out:
# /content/nlp-assignment-2

# %%
# !python main.py --cuda --epochs 1
# Out:
# | epoch   1 |   200/ 2983 batches | lr 20.00 | ms/batch 48.41 | loss  7.63 | ppl  2068.24
# | epoch   1 |   400/ 2983 batches | lr 20.00 | ms/batch 46.70 | loss  6.86 | ppl   953.24
# | epoch   1 |   600/ 2983 batches | lr 20.00 | ms/batch 46.78 | loss  6.50 | ppl   663.25
# | epoch   1 |   800/ 2983 batches | lr 20.00 | ms/batch 46.68 | loss  6.30 | ppl   544.83
# | epoch   1 |  1000/ 2983 batches | lr 20.00 | ms/batch 46.65 | loss  6.16 | ppl   471.85
# | epoch   1 |  1200/ 2983 batches | lr 20.00 | ms/batch 46.55 | loss  6.07 | ppl   432.85
# | epoch   1 |  1400/ 2983 batches | lr 20.00 | ms/batch 46.45 | loss  5.96 | ppl   387.37
# | epoch   1 |  1600/ 2983 batches | lr 20.00 | ms/batch 46.48 | loss  5.96 | ppl   388.76
# | epoch   1 |  1800/ 2983 batches | lr 20.00 | ms/batch 46.37 | loss  5.82 | ppl   336.07
# | epoch   1 |  2000/ 2983 batches | lr 20.00 | ms/batch 46.44 | loss  5.80 | ppl   330.01
# ...

# %%
# !python main.py --model FNN --cuda --epochs 1
# Out:
# | epoch   1 |   200/ 2983 batches | lr 20.00 | ms/batch 36.38 | loss  7.93 | ppl  2790.71
# | epoch   1 |   400/ 2983 batches | lr 20.00 | ms/batch 34.42 | loss  6.94 | ppl  1035.25
# | epoch   1 |   600/ 2983 batches | lr 20.00 | ms/batch 34.64 | loss  6.59 | ppl   725.42
# | epoch   1 |   800/ 2983 batches | lr 20.00 | ms/batch 34.94 | loss  6.47 | ppl   644.27
# | epoch   1 |  1000/ 2983 batches | lr 20.00 | ms/batch 35.10 | loss  6.36 | ppl   575.92
# | epoch   1 |  1200/ 2983 batches | lr 20.00 | ms/batch 35.11 | loss  6.33 | ppl   559.57
# | epoch   1 |  1400/ 2983 batches | lr 20.00 | ms/batch 35.13 | loss  6.28 | ppl   535.65
# | epoch   1 |  1600/ 2983 batches | lr 20.00 | ms/batch 35.16 | loss  6.29 | ppl   539.57
# | epoch   1 |  1800/ 2983 batches | lr 20.00 | ms/batch 35.12 | loss  6.17 | ppl   479.52
# | epoch   1 |  2000/ 2983 batches | lr 20.00 | ms/batch 35.15 | loss  6.19 | ppl   486.80
# ...

# %%
# !python main.py --model FNN --cuda --epochs 50 --emsize 8 --opt SGD --save ./models/model-SGD-50ep-8gram.pt
# Out:
# | epoch   1 |   200/ 2983 batches | lr 20.00 | ms/batch 32.36 | loss  8.11 | ppl  3334.74
# | epoch   1 |   400/ 2983 batches | lr 20.00 | ms/batch 32.16 | loss  7.11 | ppl  1222.64
# | epoch   1 |   600/ 2983 batches | lr 20.00 | ms/batch 32.34 | loss  6.84 | ppl   935.60
# | epoch   1 |   800/ 2983 batches | lr 20.00 | ms/batch 32.44 | loss  6.73 | ppl   838.86
# | epoch   1 |  1000/ 2983 batches | lr 20.00 | ms/batch 32.46 | loss  6.68 | ppl   797.28
# | epoch   1 |  1200/ 2983 batches | lr 20.00 | ms/batch 32.57 | loss  6.66 | ppl   780.98
# | epoch   1 |  1400/ 2983 batches | lr 20.00 | ms/batch 32.58 | loss  6.62 | ppl   751.81
# | epoch   1 |  1600/ 2983 batches | lr 20.00 | ms/batch 32.58 | loss  6.64 | ppl   766.89
# | epoch   1 |  1800/ 2983 batches | lr 20.00 | ms/batch 32.53 | loss  6.54 | ppl   692.43
# | epoch   1 |  2000/ 2983 batches | lr 20.00 | ms/batch 32.52 | loss  6.57 | ppl   716.42
# ...

# %%
# !python main.py --model FNN --cuda --epochs 50 --emsize 8 --opt Adam --save ./models/model-Adam-50ep-8gram.pt
# Out:
# | epoch   1 |   200/ 2983 batches | lr 20.00 | ms/batch 35.78 | loss  7.92 | ppl  2742.22
# | epoch   1 |   400/ 2983 batches | lr 20.00 | ms/batch 35.35 | loss  7.02 | ppl  1118.33
# | epoch   1 |   600/ 2983 batches | lr 20.00 | ms/batch 35.31 | loss  6.77 | ppl   868.17
# | epoch   1 |   800/ 2983 batches | lr 20.00 | ms/batch 35.26 | loss  6.69 | ppl   802.98
# | epoch   1 |  1000/ 2983 batches | lr 20.00 | ms/batch 35.29 | loss  6.63 | ppl   757.42
# | epoch   1 |  1200/ 2983 batches | lr 20.00 | ms/batch 35.30 | loss  6.62 | ppl   753.30
# | epoch   1 |  1400/ 2983 batches | lr 20.00 | ms/batch 35.31 | loss  6.60 | ppl   733.34
# | epoch   1 |  1600/ 2983 batches | lr 20.00 | ms/batch 35.32 | loss  6.60 | ppl   737.26
# | epoch   1 |  1800/ 2983 batches | lr 20.00 | ms/batch 35.25 | loss  6.51 | ppl   670.61
# | epoch   1 |  2000/ 2983 batches | lr 20.00 | ms/batch 35.25 | loss  6.54 | ppl   692.01
# ...

# %%
# !python main.py --model FNN --cuda --epochs 50 --emsize 8 --opt RMSprop --save ./models/model-RMSprop-50ep-8gram.pt
# Out:
# | epoch   1 |   200/ 2983 batches | lr 20.00 | ms/batch 33.83 | loss  7.93 | ppl  2787.86
# | epoch   1 |   400/ 2983 batches | lr 20.00 | ms/batch 33.43 | loss  7.02 | ppl  1116.57
# | epoch   1 |   600/ 2983 batches | lr 20.00 | ms/batch 33.39 | loss  6.75 | ppl   856.52
# | epoch   1 |   800/ 2983 batches | lr 20.00 | ms/batch 33.38 | loss  6.69 | ppl   802.02
# | epoch   1 |  1000/ 2983 batches | lr 20.00 | ms/batch 33.37 | loss  6.63 | ppl   759.59
# | epoch   1 |  1200/ 2983 batches | lr 20.00 | ms/batch 33.41 | loss  6.64 | ppl   761.81
# | epoch   1 |  1400/ 2983 batches | lr 20.00 | ms/batch 33.37 | loss  6.60 | ppl   733.24
# | epoch   1 |  1600/ 2983 batches | lr 20.00 | ms/batch 33.37 | loss  6.61 | ppl   740.57
# | epoch   1 |  1800/ 2983 batches | lr 20.00 | ms/batch 33.38 | loss  6.54 | ppl   695.21
# | epoch   1 |  2000/ 2983 batches | lr 20.00 | ms/batch 33.37 | loss  6.54 | ppl   693.17
# ...

# %%
sgd_perplexities = [614.96, 631.63, 390.25, 397.72, 368.14, 367.7, 365.9, 364.53, 362.96, 360.24, 359.16, 356.75, 354.2, 353.43, 351.04, 349.81, 348.17, 345.96, 346.26, 314.16, 314.05, 313.32, 313.61, 300.36, 299.81, 299.58, 299.8, 297.23, 296.9, 296.93, 296.37, 296.24, 296.21, 296.18, 296.17, 296.27, 296.12, 296.11, 296.05, 296.07, 296.05, 296.07, 296.05, 295.99, 296.05, 296.03, 296.03, 296.11, 296.1, 296.06]
adam_perplexities = [469.84, 558.23, 426.69, 451.75, 410.73, 416.31, 403.16, 404.11, 394.07, 393.25, 391.69, 391.49, 391.16, 390.46, 391.31, 387.63, 385.73, 385.52, 386.41, 385.67, 385.72, 386.3, 388.0, 387.89, 388.43, 389.35, 389.5, 390.28, 392.09, 392.71, 391.38, 393.87, 392.42, 393.44, 393.95, 394.38, 394.33, 395.35, 395.42, 394.7, 394.89, 393.91, 395.23, 395.29, 394.12, 395.59, 395.24, 394.62, 395.2, 396.27]
rmsprop_perplexities = [566.98, 576.44, 456.38, 482.93, 448.93, 454.19, 415.4, 415.79, 411.78, 409.61, 407.35, 406.04, 407.22, 406.62, 406.51, 403.43, 402.88, 404.06, 404.23, 403.06, 403.31, 402.99, 404.0, 403.91, 403.47, 404.19, 404.99, 402.07, 404.1, 404.98, 403.21, 405.83, 403.34, 402.38, 407.05, 403.65, 404.18, 403.03, 402.56, 400.61, 400.87, 399.2, 401.74, 403.74, 404.26, 404.63, 405.64, 405.92, 405.22, 403.55]

# %%
print(sgd_perplexities)
print(adam_perplexities)
print(rmsprop_perplexities)
# Out:
# [614.96, 631.63, 390.25, 397.72, 368.14, 367.7, 365.9, 364.53, 362.96, 360.24, 359.16, 356.75, 354.2, 353.43, 351.04, 349.81, 348.17, 345.96, 346.26, 314.16, 314.05, 313.32, 313.61, 300.36, 299.81, 299.58, 299.8, 297.23, 296.9, 296.93, 296.37, 296.24, 296.21, 296.18, 296.17, 296.27, 296.12, 296.11, 296.05, 296.07, 296.05, 296.07, 296.05, 295.99, 296.05, 296.03, 296.03, 296.11, 296.1, 296.06]
# [469.84, 558.23, 426.69, 451.75, 410.73, 416.31, 403.16, 404.11, 394.07, 393.25, 391.69, 391.49, 391.16, 390.46, 391.31, 387.63, 385.73, 385.52, 386.41, 385.67, 385.72, 386.3, 388.0, 387.89, 388.43, 389.35, 389.5, 390.28, 392.09, 392.71, 391.38, 393.87, 392.42, 393.44, 393.95, 394.38, 394.33, 395.35, 395.42, 394.7, 394.89, 393.91, 395.23, 395.29, 394.12, 395.59, 395.24, 394.62, 395.2, 396.27]
# ...

# %%
import pylab as pyl

# %%
pyl.plot(sgd_perplexities)
pyl.title('SGD validation perplexities')
pyl.ylabel('val ppl')
pyl.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
pyl.plot(adam_perplexities)
pyl.title('Adam validation perplexities')
pyl.ylabel('val ppl')
pyl.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
pyl.plot(rmsprop_perplexities)
pyl.title('RMSprop validation perplexities')
pyl.ylabel('val ppl')
pyl.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
pyl.plot(sgd_perplexities)
pyl.plot(adam_perplexities)
pyl.plot(rmsprop_perplexities)
pyl.title('Optimizers validation perplexities')
pyl.ylabel('val ppl')
pyl.xlabel('epoch')
pyl.legend(['SGD', 'Adam', 'RMSprop'])

# %%
# !python generate.py --cuda --checkpoint ./models/model-SGD-50ep-8gram.pt --words 500 --outf ./generated-text/text-SGD-50ep-8gram.txt
# Out:
# | Generated 0/500 words
# | Generated 100/500 words
# | Generated 200/500 words
# | Generated 300/500 words
# | Generated 400/500 words

# %%
# !python generate.py --cuda --checkpoint ./models/model-Adam-50ep-8gram.pt --words 500 --outf ./generated-text/text-Adam-50ep-8gram.txt
# Out:
# | Generated 0/500 words
# | Generated 100/500 words
# | Generated 200/500 words
# | Generated 300/500 words
# | Generated 400/500 words

# %%
# !python generate.py --cuda --checkpoint ./models/model-RMSprop-50ep-8gram.pt --words 500 --outf ./generated-text/text-RMSprop-50ep-8gram.txt
# Out:
# | Generated 0/500 words
# | Generated 100/500 words
# | Generated 200/500 words
# | Generated 300/500 words
# | Generated 400/500 words
