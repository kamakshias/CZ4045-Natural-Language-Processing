# %%
# !git clone https://github.com/AtrikDas/nlp-assignment-2.git
# Out:
# Cloning into 'nlp-assignment-2'...
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 33 (delta 15), reused 25 (delta 7), pack-reused 0
# Unpacking objects: 100% (33/33), done.

# %%
cd 'nlp-assignment-2'
# Out:
# /content/nlp-assignment-2

# %%
import pylab as pyl

# %%
# !python main.py --tied --model FNN --cuda --epochs 50 --emsize 8 --nhid 8 --opt SGD --save ./models/model-SGD-50ep-8gram-tied.pt
# Out:
# | epoch   1 |   200/ 2983 batches | lr 20.00 | ms/batch 15.22 | loss  7.73 | ppl  2286.59
# | epoch   1 |   400/ 2983 batches | lr 20.00 | ms/batch 13.42 | loss  7.20 | ppl  1336.36
# | epoch   1 |   600/ 2983 batches | lr 20.00 | ms/batch 13.37 | loss  7.02 | ppl  1115.01
# | epoch   1 |   800/ 2983 batches | lr 20.00 | ms/batch 13.40 | loss  6.96 | ppl  1058.58
# | epoch   1 |  1000/ 2983 batches | lr 20.00 | ms/batch 13.36 | loss  6.95 | ppl  1041.82
# | epoch   1 |  1200/ 2983 batches | lr 20.00 | ms/batch 13.35 | loss  6.95 | ppl  1038.27
# | epoch   1 |  1400/ 2983 batches | lr 20.00 | ms/batch 13.34 | loss  6.89 | ppl   981.85
# | epoch   1 |  1600/ 2983 batches | lr 20.00 | ms/batch 13.36 | loss  6.91 | ppl  1000.12
# | epoch   1 |  1800/ 2983 batches | lr 20.00 | ms/batch 13.26 | loss  6.87 | ppl   962.12
# | epoch   1 |  2000/ 2983 batches | lr 20.00 | ms/batch 13.35 | loss  6.87 | ppl   958.98
# ...

# %%
SGD_perplexities = [774.03, 770.16, 760.19, 768.95, 505.12, 505.49, 487.45, 483.08, 486.09, 478.44, 479.23, 476.04, 475.86, 475.70, 475.54, 475.58, 474.86, 474.75, 474.93, 474.85, 474.94, 474.88, 474.87, 474.75, 474.84, 474.82, 474.89, 474.75, 474.73, 474.73, 474.69, 474.66, 474.73, 474.70, 474.66, 474.69, 474.62, 474.77, 474.64, 474.67, 474.68, 474.69, 474.56, 474.68, 474.66, 474.66, 474.69, 474.64, 474.64, 474.56]

# %%
pyl.plot(SGD_perplexities)
pyl.title('SGD validation perplexities')
pyl.ylabel('val ppl')
pyl.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
# !python main.py --tied --model FNN --cuda --epochs 50 --emsize 8 --nhid 8 --opt Adam --save ./models/model-Adam-50ep-8gram-tied.pt
# Out:
# | epoch   1 |   200/ 2983 batches | lr 20.00 | ms/batch 13.76 | loss  7.69 | ppl  2190.57
# | epoch   1 |   400/ 2983 batches | lr 20.00 | ms/batch 13.42 | loss  7.24 | ppl  1394.92
# | epoch   1 |   600/ 2983 batches | lr 20.00 | ms/batch 13.37 | loss  7.02 | ppl  1116.54
# | epoch   1 |   800/ 2983 batches | lr 20.00 | ms/batch 13.36 | loss  6.97 | ppl  1060.58
# | epoch   1 |  1000/ 2983 batches | lr 20.00 | ms/batch 13.37 | loss  6.96 | ppl  1049.06
# | epoch   1 |  1200/ 2983 batches | lr 20.00 | ms/batch 13.39 | loss  6.98 | ppl  1076.44
# | epoch   1 |  1400/ 2983 batches | lr 20.00 | ms/batch 13.43 | loss  6.94 | ppl  1037.92
# | epoch   1 |  1600/ 2983 batches | lr 20.00 | ms/batch 13.37 | loss  6.98 | ppl  1079.06
# | epoch   1 |  1800/ 2983 batches | lr 20.00 | ms/batch 13.37 | loss  6.91 | ppl  1006.24
# | epoch   1 |  2000/ 2983 batches | lr 20.00 | ms/batch 13.38 | loss  6.94 | ppl  1030.19
# ...

# %%
Adam_perplexities = [833.91, 837.56, 506.24, 508.52, 494.66, 502.90, 502.60, 508.26, 516.81, 523.99, 529.60, 533.91, 537.01, 539.25, 541.88, 545.66, 549.84, 552.33, 554.32, 556.80, 559.02, 562.08, 563.51, 565.60, 569.76, 571.19, 575.82, 579.90, 595.58, 613.51, 622.03, 619.16, 608.56, 570.48, 553.28, 542.15, 538.81, 544.30, 560.26, 574.51, 585.26, 597.90, 610.79, 622.46, 631.56, 642.39, 651.50, 659.64, 670.61, 670.98]

# %%
pyl.plot(Adam_perplexities)
pyl.title('Adam validation perplexities')
pyl.ylabel('val ppl')
pyl.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
# !python main.py --tied --model FNN --cuda --epochs 50 --emsize 8 --nhid 8 --opt RMSprop --save ./models/model-RMSprop-50ep-8gram-tied.pt
# Out:
# | epoch   1 |   200/ 2983 batches | lr 20.00 | ms/batch 13.88 | loss  7.64 | ppl  2077.33
# | epoch   1 |   400/ 2983 batches | lr 20.00 | ms/batch 13.42 | loss  7.25 | ppl  1408.06
# | epoch   1 |   600/ 2983 batches | lr 20.00 | ms/batch 13.44 | loss  7.09 | ppl  1194.50
# | epoch   1 |   800/ 2983 batches | lr 20.00 | ms/batch 13.48 | loss  6.98 | ppl  1075.07
# | epoch   1 |  1000/ 2983 batches | lr 20.00 | ms/batch 13.40 | loss  6.94 | ppl  1027.92
# | epoch   1 |  1200/ 2983 batches | lr 20.00 | ms/batch 13.44 | loss  6.93 | ppl  1021.35
# | epoch   1 |  1400/ 2983 batches | lr 20.00 | ms/batch 13.39 | loss  6.90 | ppl   988.72
# | epoch   1 |  1600/ 2983 batches | lr 20.00 | ms/batch 13.35 | loss  6.92 | ppl  1017.22
# | epoch   1 |  1800/ 2983 batches | lr 20.00 | ms/batch 13.36 | loss  6.86 | ppl   957.32
# | epoch   1 |  2000/ 2983 batches | lr 20.00 | ms/batch 13.41 | loss  6.87 | ppl   958.46
# ...

# %%
RMSprop_perplexities = [826.19, 803.95, 755.28, 765.33, 556.53, 571.70, 569.77, 586.11, 604.65, 618.14, 630.36, 637.84, 644.31, 649.80, 654.91, 657.84, 659.23, 661.53, 662.29, 664.87, 669.50, 670.74, 672.83, 673.92, 675.07, 677.21, 677.37, 678.59, 680.11, 680.90, 681.53, 683.23, 685.81, 687.18, 688.56, 689.74, 692.12, 692.02, 693.13, 695.20, 698.25, 700.37, 699.56, 702.69, 704.45, 704.79, 706.41, 707.33, 707.48, 709.39]

# %%
pyl.plot(RMSprop_perplexities)
pyl.title('RMSprop validation perplexities')
pyl.ylabel('val ppl')
pyl.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
pyl.plot(SGD_perplexities)
pyl.plot(Adam_perplexities)
pyl.plot(RMSprop_perplexities)
pyl.title('Optimizers validation perplexities')
pyl.ylabel('val ppl')
pyl.xlabel('epoch')
pyl.legend(['SGD', 'Adam', 'RMSprop'], loc='upper right')

# %%
# !python generate.py --cuda --checkpoint ./models/model-SGD-50ep-8gram-tied.pt --words 500 --outf ./generated-text/text-SGD-50ep-8gram-tied.txt
# Out:
# | Generated 0/500 words
# | Generated 100/500 words
# | Generated 200/500 words
# | Generated 300/500 words
# | Generated 400/500 words

# %%
# !python generate.py --cuda --checkpoint ./models/model-Adam-50ep-8gram-tied.pt --words 500 --outf ./generated-text/text-Adam-50ep-8gram-tied.txt
# Out:
# | Generated 0/500 words
# | Generated 100/500 words
# | Generated 200/500 words
# | Generated 300/500 words
# | Generated 400/500 words

# %%
# !python generate.py --cuda --checkpoint ./models/model-RMSprop-50ep-8gram-tied.pt --words 500 --outf ./generated-text/text-RMSprop-50ep-8gram-tied.txt
# Out:
# | Generated 0/500 words
# | Generated 100/500 words
# | Generated 200/500 words
# | Generated 300/500 words
# | Generated 400/500 words
